# %%
import zipfile
with zipfile.ZipFile("C:/Users/Navya Manepalli/Downloads/shuffled-full-set-hashed.csv","r") as zip_ref:
    zip_ref.extractall("C:/Users/Navya Manepalli/Downloads/Navya_BKFS")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-15b205695e73> in <module>
#       1 import zipfile
# ----> 2 with zipfile.ZipFile("C:/Users/Navya Manepalli/Downloads/shuffled-full-set-hashed.csv","r") as zip_ref:
#       3     zip_ref.extractall("C:/Users/Navya Manepalli/Downloads/Navya_BKFS")
#
# ~\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1205             while True:
#    1206                 try:
# -> 1207                     self.fp = io.open(file, filemode)
#    1208                 except OSError:
#    1209                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Navya Manepalli/Downloads/shuffled-full-set-hashed.csv'

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from matplotlib import pyplot as plt 
import seaborn as sns

# %%
bkfs_data = pd.read_csv("C:/Users/Navya Manepalli/Downloads/BKFS.csv")

# %%
heavy_data=pd.read_csv("C:/Users/Navya Manepalli/Downloads/shuffled-full-set-hashed/shuffled-full-set-hashed.csv", names=['doc_cat','data'])
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-1864310599a9> in <module>
# ----> 1 heavy_data=pd.read_csv("C:/Users/Navya Manepalli/Downloads/shuffled-full-set-hashed/shuffled-full-set-hashed.csv", names=['doc_cat','data'])
#
# ...

# %%
bkfs_data.describe()
# Out:
#        Doc_Type                                               Data
# count     62424                                              62159
# unique      225                                              60176
# top        BILL  bf064c332aa1 079935e500e5 1a4dd36c6de0 7efa289...
# freq      18968                                                 11

# %%
bkfs_data.head()
# Out:
#                Doc_Type                                               Data
# 0  DELETION OF INTEREST  e04a09c87692 d6b72e591b91 5d066f0246f1 ed41171...
# 1        RETURNED CHECK  a3b334c6eefd be95012ebf2b 41d67080e078 ff1c26e...
# 2                  BILL  586242498a88 9ccf259ca087 54709b24b45f 6bf9c0c...
# 3                  BILL  cd50e861f48b 6ca2dd348663 d38820625542 f077614...
# 4                  BILL  9db5536263d8 1c303d15eb65 3f89b4673455 b73e657...

# %%
bkfs_data.tail()
# Out:
#                   Doc_Type                                               Data
# 62467  CANCELLATION NOTICE  6bf9c0cb01b4 52102c70348d 1b6d0614f2c7 246ee0c...
# 62468               BINDER  816aed74475e 288ccf089872 fe33912c5732 5d00ab6...
# 62469                 BILL  f95d0bea231b 894305951372 c9a53ea6e219 8f6018d...
# 62470  CANCELLATION NOTICE  5ee06767bc0f 106de4332a24 46a0c35e916c 54709b2...
# 62471  CANCELLATION NOTICE  586242498a88 21e314d3afcc 818a7ff3bf29 4e43b72...

# %%
bkfs_data.hist(column='Doc_Type')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-496293fc7b4a> in <module>
# ----> 1 bkfs_data.hist(column='Doc_Type')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#     197         layout=layout,
#     198         bins=bins,
# --> 199         **kwds
#     200     )
#     201
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#     395
#     396     if naxes == 0:
# --> 397         raise ValueError("hist method requires numerical columns, " "nothing to plot.")
#     398
#     399     fig, axes = _subplots(
#
# ValueError: hist method requires numerical columns, nothing to plot.

# %%
import pandasql as ps


q1 = """select distinct Doc_Type from bkfs_data limit 15"""

print(ps.sqldf(q1, locals()))
# Out:
#                                              Doc_Type
# 0                                DELETION OF INTEREST
# 1                                      RETURNED CHECK
# 2                                                BILL
# 3                                       POLICY CHANGE
# 4                                 CANCELLATION NOTICE
# 5                                         DECLARATION
# 6                                  CHANGE ENDORSEMENT
# 7                                  NON-RENEWAL NOTICE
# 8                                              BINDER
# 9                                REINSTATEMENT NOTICE
# 10                                  EXPIRATION NOTICE
# 11                            INTENT TO CANCEL NOTICE
# 12                                        APPLICATION
# 13                                        BILL BINDER
# 14  19295e322731 36e7aa72ffe1 ecee69844b4e e137a75...

# %%
! pip install zipfile
# Out:
# ...
#   ERROR: Could not find a version that satisfies the requirement zipfile (from versions: none)
# ERROR: No matching distribution found for zipfile

# %%
bkfs_data.Doc_Type.value_counts()
# Out:
# BILL                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  
# ...
